# %%
# !pip install yfinance fastai scikit-learn ta
import yfinance as yf
import pandas as pd
import numpy as np
from fastai.tabular.all import *
from ta.momentum import RSIIndicator
from ta.trend import SMAIndicator
from sklearn.metrics import accuracy_score
# Out:
# DEPRECATION: Loading egg at /home/ahsinali/anaconda3/lib/python3.12/site-packages/v20-3.0.25.0-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Requirement already satisfied: yfinance in /home/ahsinali/anaconda3/lib/python3.12/site-packages (0.2.63)
# Requirement already satisfied: fastai in /home/ahsinali/anaconda3/lib/python3.12/site-packages (2.8.1)
# Requirement already satisfied: scikit-learn in /home/ahsinali/anaconda3/lib/python3.12/site-packages (1.5.1)
# Requirement already satisfied: ta in /home/ahsinali/anaconda3/lib/python3.12/site-packages (0.11.0)
# Requirement already satisfied: pandas>=1.3.0 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from yfinance) (3.10.0)
# Requirement already satisfied: pytz>=2022.5 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from yfinance) (2.4.2)
# Requirement already satisfied: peewee>=3.16.2 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from yfinance) (3.18.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: curl_cffi>=0.7 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from yfinance) (0.11.3)
# Requirement already satisfied: protobuf>=3.19.0 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from yfinance) (4.25.3)
# Requirement already satisfied: websockets>=13.0 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: pip in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from fastai) (24.2)
# Requirement already satisfied: packaging in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from fastai) (24.1)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from fastai) (0.0.7)
# Requirement already satisfied: fastcore<1.9,>=1.8.0 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from fastai) (1.8.2)
# Requirement already satisfied: fasttransform>=0.0.2 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from fastai) (0.0.2)
# Requirement already satisfied: torchvision>=0.11 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from fastai) (0.21.0)
# Requirement already satisfied: matplotlib in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from fastai) (3.9.2)
# Requirement already satisfied: pyyaml in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from fastai) (6.0.1)
# Requirement already satisfied: fastprogress>=0.2.4 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from fastai) (1.0.3)
# Requirement already satisfied: pillow>=9.0.0 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from fastai) (10.4.0)
# Requirement already satisfied: scipy in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from fastai) (1.13.1)
# Requirement already satisfied: spacy<4 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from fastai) (3.8.5)
# Requirement already satisfied: plum-dispatch in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from fastai) (2.5.7)
# Requirement already satisfied: cloudpickle in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from fastai) (3.0.0)
# Requirement already satisfied: torch<2.7,>=1.10 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from fastai) (2.6.0)
# Requirement already satisfied: joblib>=1.2.0 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: soupsieve>1.2 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: cffi>=1.12.0 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from curl_cffi>=0.7->yfinance) (1.17.1)
# Requirement already satisfied: certifi>=2024.2.2 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from curl_cffi>=0.7->yfinance) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from requests>=2.31->yfinance) (2.2.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from spacy<4->fastai) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from spacy<4->fastai) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from spacy<4->fastai) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from spacy<4->fastai) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from spacy<4->fastai) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from spacy<4->fastai) (8.3.4)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from spacy<4->fastai) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from spacy<4->fastai) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from spacy<4->fastai) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from spacy<4->fastai) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from spacy<4->fastai) (0.15.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from spacy<4->fastai) (4.66.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from spacy<4->fastai) (2.8.2)
# Requirement already satisfied: jinja2 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from spacy<4->fastai) (3.1.4)
# Requirement already satisfied: setuptools in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from spacy<4->fastai) (75.1.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from spacy<4->fastai) (3.5.0)
# Requirement already satisfied: filelock in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from torch<2.7,>=1.10->fastai) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from torch<2.7,>=1.10->fastai) (4.11.0)
# Requirement already satisfied: networkx in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from torch<2.7,>=1.10->fastai) (3.3)
# Requirement already satisfied: fsspec in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from torch<2.7,>=1.10->fastai) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from torch<2.7,>=1.10->fastai) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from torch<2.7,>=1.10->fastai) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from torch<2.7,>=1.10->fastai) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from torch<2.7,>=1.10->fastai) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from torch<2.7,>=1.10->fastai) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from torch<2.7,>=1.10->fastai) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from torch<2.7,>=1.10->fastai) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from torch<2.7,>=1.10->fastai) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from torch<2.7,>=1.10->fastai) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from torch<2.7,>=1.10->fastai) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from torch<2.7,>=1.10->fastai) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from torch<2.7,>=1.10->fastai) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from torch<2.7,>=1.10->fastai) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from torch<2.7,>=1.10->fastai) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from torch<2.7,>=1.10->fastai) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from sympy==1.13.1->torch<2.7,>=1.10->fastai) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from matplotlib->fastai) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from matplotlib->fastai) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from matplotlib->fastai) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from matplotlib->fastai) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from matplotlib->fastai) (3.1.2)
# Requirement already satisfied: beartype>=0.16.2 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from plum-dispatch->fastai) (0.20.2)
# Requirement already satisfied: rich>=10.0 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from plum-dispatch->fastai) (13.7.1)
# Requirement already satisfied: pycparser in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.21)
# Requirement already satisfied: language-data>=1.2 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from langcodes<4.0.0,>=3.2.0->spacy<4->fastai) (1.3.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai) (2.20.1)
# Requirement already satisfied: six>=1.5 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from rich>=10.0->plum-dispatch->fastai) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from rich>=10.0->plum-dispatch->fastai) (2.15.1)
# Requirement already satisfied: blis<1.3.0,>=1.2.0 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from thinc<8.4.0,>=8.3.4->spacy<4->fastai) (1.2.1)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from thinc<8.4.0,>=8.3.4->spacy<4->fastai) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy<4->fastai) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy<4->fastai) (1.5.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from weasel<0.5.0,>=0.1.0->spacy<4->fastai) (0.21.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from weasel<0.5.0,>=0.1.0->spacy<4->fastai) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from jinja2->spacy<4->fastai) (2.1.3)
# Requirement already satisfied: marisa-trie>=1.1.0 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<4->fastai) (1.2.1)
# Requirement already satisfied: mdurl~=0.1 in /home/ahsinali/anaconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.0->plum-dispatch->fastai) (0.1.0)

# %%
def download_stock_data(ticker, start_date, end_date):
    df = yf.download(ticker, start=start_date, end=end_date)
    df.reset_index(inplace=True)
    return df

# %%
def add_technical_indicators(df):
    # RSI (14 period)
    rsi = RSIIndicator(close=df['Close'].squeeze(), window=14)
    df['RSI'] = rsi.rsi()
    
    # SMAs
    sma10 = SMAIndicator(close=df['Close'].squeeze(), window=10)
    df['SMA_10'] = sma10.sma_indicator()
    
    sma50 = SMAIndicator(close=df['Close'].squeeze(), window=50)
    df['SMA_50'] = sma50.sma_indicator()
    
    # Create target - next day's price direction (1 if up, 0 if down)
    df['Target'] = (df['Close'].squeeze().shift(-1) > df['Close'].squeeze()).astype(int)
    df['Target'] = df['Target'].astype(int).astype(str)
    # Drop rows with NaN values (from indicator calculations)
    df.dropna(inplace=True)
    
    return df

# %%
ticker = 'AAPL'
start_date = '2020-01-01'
end_date = '2023-12-31'

raw_data = download_stock_data(ticker, start_date, end_date)
# Out:
# /tmp/ipykernel_2218/4155398115.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start=start_date, end=end_date)
# [*********************100%***********************]  1 of 1 completed

# %%
# raw_data = raw_data.reset_index(drop=True)

raw_data.columns = raw_data.columns.get_level_values(0)

# Remove any multi-index on rows
raw_data = raw_data.reset_index(drop=True)
raw_data.head()
# Out:
# Price       Date      Close       High        Low       Open     Volume
# 0     2020-01-02  72.620819  72.681266  71.373196  71.627069  135480400
# 1     2020-01-03  71.914810  72.676439  71.689950  71.847110  146322800
# 2     2020-01-06  72.487869  72.526556  70.783271  71.034732  118387200
# 3     2020-01-07  72.146927  72.753808  71.926900  72.497514  108872000
# 4     2020-01-08  73.307510  73.609745  71.849533  71.849533  132079200

# %%
data = add_technical_indicators(raw_data)

# %%
data.head()
# Out:
# Price       Date      Close       High        Low       Open     Volume  \
# 49    2020-03-13  67.369148  67.841756  61.305270  64.199067  370732000
# 50    2020-03-16  58.702312  62.790941  58.166693  58.639296  322423600
# 51    2020-03-17  61.283451  62.434663  57.778907  59.986817  324056000
# 52    2020-03-18  59.783241  60.590305  57.468691  58.110950  300233600
# 53    2020-03-19  59.325180  61.278611  58.799257  59.957743  271857200
#
# Price        RSI     SMA_10     SMA_50 Target
# 49     45.241601  68.490311  74.025906      0
# 50     36.847040  67.118546  73.747536      1
# 51     40.394225  66.234896  73.534909      0
# 52     39.022306  64.875977  73.280816      0
# 53     38.591328  63.709251  73.024382      0

# %%
def prepare_tabular_data(df):
    # Define features and target
    cont_names = ['Open', 'High', 'Low', 'Close', 'Volume', 'RSI', 'SMA_10', 'SMA_50']
    dep_var = 'Target'
    
    # Split data into train and validation sets (time-based split)
    split_idx = int(0.8 * len(df))
    train_df = df.iloc[:split_idx].copy()
    valid_df = df.iloc[split_idx:].copy()
    
    # TabularPandas for preprocessing
    procs = [Categorify, FillMissing, Normalize]
    to = TabularPandas(train_df, procs=procs, cat_names=[], 
                       cont_names=cont_names, y_names=dep_var,y_block=CategoryBlock(),
                       splits=RandomSplitter(valid_pct=0.2)(range_of(train_df)))
    
    return to, cont_names, dep_var

# %%
to, cont_names, dep_var = prepare_tabular_data(data)

# %%
raw_data.iloc[:10].copy()
# Out:
# Price       Date      Close       High        Low       Open     Volume  \
# 49    2020-03-13  67.369148  67.841756  61.305270  64.199067  370732000
# 50    2020-03-16  58.702312  62.790941  58.166693  58.639296  322423600
# 51    2020-03-17  61.283451  62.434663  57.778907  59.986817  324056000
# 52    2020-03-18  59.783241  60.590305  57.468691  58.110950  300233600
# 53    2020-03-19  59.325180  61.278611  58.799257  59.957743  271857200
# 54    2020-03-20  55.558884  61.033822  55.258354  59.906841  401693200
# 55    2020-03-23  54.378578  55.379531  51.528412  55.277740  336752800
# 56    2020-03-24  59.834122  60.030434  56.785218  57.284481  287531200
# 57    2020-03-25  59.504528  62.589785  59.208847  60.772076  303602000
# 58    2020-03-26  62.635818  62.693983  59.708095  59.746874  252087200
#
# Price        RSI     SMA_10     SMA_50 Target
# 49     45.241601  68.490311  74.025906      0
# 50     36.847040  67.118546  73.747536      1
# 51     40.394225  66.234896  73.534909      0
# 52     39.022306  64.875977  73.280816      0
# 53     38.591328  63.709251  73.024382      0
# 54     35.153485  62.260175  72.669409      0
# 55     34.127444  61.247102  72.259688      1
# 56     42.483765  60.314979  71.955693      0
# 57     42.135997  59.590076  71.613045      1
# 58     46.607712  59.837526  71.353720      0

# %%
dls = to.dataloaders(bs=64)

# %%
def train_model(dls, metrics=[accuracy]):
    learn = tabular_learner(dls, layers=[200, 100], metrics=metrics)
    learn.fit_one_cycle(10, 1e-2)
    return learn

learn = train_model(dls)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.729987</td>
#       <td>0.717202</td>
#       <td>0.483660</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.746577</td>
#       <td>0.780278</td>
#       <td>0.464052</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.724027</td>
#       <td>0.885180</td>
#       <td>0.444444</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.711110</td>
#       <td>0.948991</td>
#       <td>0.437909</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.706953</td>
#       <td>0.789762</td>
#       <td>0.470588</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.697552</td>
#       <td>0.892721</td>
#       <td>0.437909</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.698952</td>
#       <td>0.728584</td>
#       <td>0.555556</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.696968</td>
#       <td>0.761221</td>
#       <td>0.477124</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.692524</td>
#       <td>0.824721</td>
#       <td>0.450980</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.693946</td>
#       <td>0.816147</td>
#       <td>0.457516</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table>

# %%
def backtest(model, df, cont_names, initial_capital=10000, commission=0.001):
    """
    Backtest the model over the last 6 months of data
    Returns accuracy and portfolio value over time
    """
    # Get the last 6 months of data
    test_df = df.iloc[-126:]  # ~6 months of trading days
    
    # Create test dataloader
    test_dl = model.dls.test_dl(test_df[cont_names + ['Target']])

    # Get predictions
    preds , _  = model.get_preds(dl=test_dl)
 
    predicted_directions = preds.argmax(dim=1).numpy()
    actual_directions = test_df['Target'].values.astype(int)
    # Calculate accuracy
    accuracy = accuracy_score(actual_directions, predicted_directions)
    
    # Simulate trading
    capital = initial_capital
    position = 0
    portfolio_values = []
    
    for i in range(len(test_df)):
        current_price = test_df.iloc[i]['Close']
        prediction = predicted_directions[i]
        
        # Close existing position
        if position != 0:
            capital += position * current_price * (1 - commission)
            position = 0
        
        # Open new position based on prediction
        if prediction:  # Predicts up
            position = capital / current_price
            capital = 0
        
        # Record portfolio value
        portfolio_value = capital + position * current_price if position != 0 else capital
        portfolio_values.append(portfolio_value)
    
    # Calculate returns
    returns = (portfolio_values[-1] - initial_capital) / initial_capital * 100
    
    return accuracy, returns, portfolio_values

# Run backtest
accuracy, returns, portfolio_values = backtest(learn, data, cont_names)
print(f"Backtest Accuracy: {accuracy:.2%}")
print(f"Backtest Returns: {returns:.2f}%")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Backtest Accuracy: 45.24%
# Backtest Returns: 0.00%

# %%
model_path = 'stock_direction_model'
learn.export(model_path + '.pkl')

# Load model
loaded_learn = load_learner(model_path + '.pkl')

# Test loaded model
test_row = data.iloc[-1:][cont_names]
pred, _, probs = loaded_learn.predict(test_row.iloc[0])
print(f"Prediction: {pred}, Probability: {probs[0].item():.2%}")
# Out:
# /home/ahsinali/anaconda3/lib/python3.12/site-packages/fastai/learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Prediction:        Open      High       Low     Close   Volume       RSI    SMA_10  \
# 0  2.270297  2.200969  2.269889  2.209561 -1.27614 -0.249253  2.293045
#
#      SMA_50  Target
# 0  2.012524     0.0  , Probability: 96.16%

# %%
probs
# Out:
# tensor([0.9616, 0.0384])
